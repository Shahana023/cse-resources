# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahana023/cse-resources/blob/main/AI_Lab_workbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# BFS Implementation

def bfs(graph, start):
    visited = set()
    queue = [(start, [start])]

    while queue:
        node, path = queue.pop(0)
        if node not in visited:
            print(node, end=" ")
            visited.add(node)

            for n in graph.get(node, set()):
                if n not in visited:
                    queue.append((n, path + [n]))


# Create the graph
graph = {}
nodes = int(input("Enter number of nodes: "))
edges = int(input("Enter number of edges: "))

for _ in range(edges):
    n1, n2 = input("Enter the edge (node1 node2): ").split()
    graph.setdefault(n1, set()).add(n2)
    graph.setdefault(n2, set()).add(n1)

start = input("Enter the starting node: ")
print("BFS Traversal:")
bfs(graph, start)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 24
#      21 edges = int(input("Enter number of edges: "))
#      23 for _ in range(edges):
# ---> 24     n1, n2 = input("Enter the edge (node1 node2): ").split()
#      25     graph.setdefault(n1, set()).add(n2)
#      26     graph.setdefault(n2, set()).add(n1)
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
# Install required packages in Colab (only needed once)
# !pip install networkx matplotlib

import networkx as nx
import matplotlib.pyplot as plt

# --- BFS FUNCTION ---
def bfs(graph, start):
    visited = set()
    queue = [(start, [start])]

    print("BFS Traversal:", end=" ")

    while queue:
        node, path = queue.pop(0)
        if node not in visited:
            print(node, end=" ")
            visited.add(node)

            for n in graph.get(node, set()):
                if n not in visited:
                    queue.append((n, path + [n]))

# --- DFS FUNCTION ---
def dfs(graph, start):
    visited = set()
    stack = [start]

    print("DFS Traversal:", end=" ")

    while stack:
        node = stack.pop()
        if node not in visited:
            print(node, end=" ")
            visited.add(node)

            # Add neighbors to the stack in reverse order to maintain a consistent traversal order
            for n in sorted(list(graph.get(node, set())), reverse=True):
                if n not in visited:
                    stack.append(n)

# --- SHORTEST PATH FUNCTION ---
def bfs_shortest_path(graph, start, end):
    """
    Finds the shortest path between a start and end node using BFS.
    """
    queue = [(start, [start])]
    visited = {start}

    while queue:
        (node, path) = queue.pop(0)

        for next_node in graph.get(node, []):
            if next_node not in visited:
                if next_node == end:
                    return path + [next_node]
                else:
                    visited.add(next_node)
                    queue.append((next_node, path + [next_node]))
    return None # Path not found

# --- CREATE GRAPH FROM USER INPUT ---
graph = {}
nodes = int(input("Enter number of nodes: "))
edges = int(input("Enter number of edges: "))

edge_list = []

for i in range(edges):
    while True:
        try:
            n1, n2 = input(f"Enter edge {i+1} (node1 node2): ").split()
            graph.setdefault(n1, set()).add(n2)
            graph.setdefault(n2, set()).add(n1)
            edge_list.append((n1, n2))
            break
        except ValueError:
            print("Invalid input. Please enter two nodes separated by a space.")

start = input("Enter the starting node: ")
print()

# --- RUN BFS AND DFS ---
bfs(graph, start)
print()
dfs(graph, start)
print()

# --- FIND AND PRINT SHORTEST PATH ---
start_node = 'a'
end_node = 'd'
shortest_path = bfs_shortest_path(graph, start_node, end_node)

if shortest_path:
    print(f"Shortest path from {start_node} to {end_node}: {' -> '.join(shortest_path)}")
else:
    print(f"No path found from {start_node} to {end_node}")


# --- DRAW GRAPH ---
G = nx.Graph()
G.add_edges_from(edge_list)

plt.figure(figsize=(8, 6))
nx.draw(G, with_labels=True, node_color='skyblue', node_size=2000, font_size=14, font_weight='bold', edge_color='gray')
plt.title("Graph Visualization", fontsize=16)
plt.show()

# %%
def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()
    visited.add(start)
    print(start, end=" ")

    for neighbor in graph.get(start, set()):
        if neighbor not in visited:
            dfs(graph, neighbor, visited)

# Example Usage:
# Create the graph
graph = {}
while True:
    try:
        nodes = int(input("Enter number of nodes: "))
        break
    except ValueError:
        print("Invalid input. Please enter an integer.")

while True:
    try:
        edges = int(input("Enter number of edges: "))
        break
    except ValueError:
        print("Invalid input. Please enter an integer.")


for i in range(edges):
    while True:
        try:
            n1, n2 = input(f"Enter edge {i+1} (node1 node2): ").split()
            graph.setdefault(n1, set()).add(n2)
            graph.setdefault(n2, set()).add(n1)
            break
        except ValueError:
            print("Invalid input. Please enter two nodes separated by a space.")

start_node = input("Enter the starting node for DFS: ")
print("DFS Traversal:")
dfs(graph, start_node)

# %%
def water_jug_problem():
    maxA, maxB = 4, 3
    visited = set()
    stack = [(0, 0)]
    
    while stack:
        A, B = stack.pop()
        if (A, B) in visited:
            continue
        visited.add((A, B))
        print(f"A: {A}, B: {B}")
        if A == 2:
            print("Goal reached")
            return

        next_states = [
            (maxA, B), (A, maxB),
            (0, B), (A, 0),
            (min(A + B, maxA), max(0, B - (maxA - A))),
            (max(0, A - (maxB - B)), min(A + B, maxB))
        ]
        for state in next_states:
            if state not in visited:
                stack.append(state)

water_jug_problem()
